# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# nba colors
nba_colors = ['#17408B','#FFFFFF', '#C9082A']
nba_blue = nba_colors[0]
nba_red = nba_colors[-1]
nba_blues = sns.light_palette(nba_blue, n_colors=10, reverse=True).as_hex()
nba_reds = sns.light_palette(nba_red, n_colors=10, reverse=True).as_hex()



nba_cmap = sns.blend_palette(nba_colors, as_cmap=True)
nba_cmap

# %%
df = pd.read_excel(io='NBA_Stats_71_Years_Updated.xlsx' )

# %%
df['Team'].unique()
# Out:
# array(['PHW', 'MNL', 'BOS', 'ROC', 'FTW', 'BAL', 'NYK', 'INO', 'SYR',
#        'MIH', 'STL', 'DET', 'CIN', 'LAL', 'CHP', 'SFW', 'CHZ', 'BLT',
#        'PHL', 'CHI', 'SEA', 'SDR', 'PHX', 'ATL', 'MIL', 'POR', 'BUF',
#        'CLE', 'HOU', 'GOS', 'KCK', 'CAP', 'WAS', 'NOJ', 'DEN', 'IND',
#        'SAN', 'NYN', 'NJN', 'SDC', 'UTH', 'DAL', 'LAC', 'SAC', 'CHH',
#        'MIA', 'MIN', 'ORL', 'TOR', 'VAN', 'UTA', 'GSW', 'PHI', 'SAS',
#        'MEM', 'NOH', 'CHA', 'NOK', 'OKC', 'BKN', 'NOP'], dtype=object)

# %%
teams = pd.read_csv('Team_namees_full.csv')
teams
# Out:
#    Prefix_name              Team Name
# 0          SEA    Seattle SuperSonics
# 1          DEN         Denver Nuggets
# 2          MNL     Minneapolis Lakers
# 3          LAC   Los Angeles Clippers
# 4          PHW  Philadelphia Warriors
# ..         ...                    ...
# 56         MEM      Memphis Grizzlies
# 57         VAN    Vancouver Grizzlies
# 58         MIL        Milwaukee Bucks
# 59         NOH    New Orleans Hornets
# 60         NOP   New Orleans Pelicans
#
# [61 rows x 2 columns]

# %%
team_mapping = dict(zip(teams['Prefix_name'], teams['Team Name']))
# df['Prefix_Team'] = df['Team'].str.lower()
df['team_name'] = df['Team'].replace(team_mapping, regex=True)
df
# Out:
#        Rank     Year  Season Start Year     Season Type  Player ID  \
# 0         1  1951-52               1951  Regular Season      76056
# 1         2  1951-52               1951  Regular Season     600012
# 2         3  1951-52               1951  Regular Season     600003
# 3         4  1951-52               1951  Regular Season      77429
# 4         5  1951-52               1951  Regular Season      76514
# ...     ...      ...                ...             ...        ...
# 33325   194  2022-23               2022        Playoffs     203648
# 33326   194  2022-23               2022        Playoffs    1628418
# 33327   194  2022-23               2022        Playoffs       2617
# 33328   194  2022-23               2022        Playoffs    1628427
# 33329   194  2022-23               2022        Playoffs    1631111
#
#                        Player     Team ID Team  Games Played  Minutes Played  \
# 0                 Paul Arizin  1610612744  PHW            66            2939
# ...

# %%
df['team_name'].unique()
# Out:
# array(['phw', 'mnl', 'Boston Celtics', 'roc', 'ftw', 'bal',
#        'New York Knicksk', 'iNew Orleans Hornets', 'syr', 'mih', 'stl',
#        'Detroit Pistons', 'cin', 'Los Angeles Lakers', 'chp', 'sfw',
#        'chz', 'blt', 'phl', 'Chicago Bulls', 'sea', 'sdr', 'Phoenix Suns',
#        'Atlanta Hawks', 'Milwaukee Bucks', 'Portland Trail Blazers',
#        'buf', 'Cleveland Cavaliers', 'Houston Rockets', 'gos', 'kck',
#        'cap', 'was', 'New Orleans Hornetsj', 'Denver Nuggets',
#        'Indiana Pacers', 'San Antonio Spursn', 'New York Knicksn', 'njn',
#        'sdc', 'uth', 'Dallas Mavericks', 'Los Angeles Clippers',
#        'Sacramento Kings', 'chh', 'Miami Heat', 'Minnesota Timberwolves',
#        'Orlando Magic', 'Toronto Raptors', 'van', 'Utah Jazz',
#        'Golden State Warriorsw', 'Philadelphia 76ers',
#        'San Antonio Spurss', 'Memphis Grizzlies', 'New Orleans Hornetsh',
#        'Charlotte Bobcats', 'New Orleans Hornetsk',
# ...

# %%
print("\nRow 0: Before ->", df['Team'][0], "| After ->", df['team_name'][0])
# print("Row 1: Before ->", data['team'][1], "| After ->", df['team'][1])
# Out:
# Row 0: Before -> PHW | After -> PHW

# %%
df['Team'].unique()
# Out:
# array(['PHW', 'MNL', 'BOS', 'ROC', 'FTW', 'BAL', 'NYK', 'INO', 'SYR',
#        'MIH', 'STL', 'DET', 'CIN', 'LAL', 'CHP', 'SFW', 'CHZ', 'BLT',
#        'PHL', 'CHI', 'SEA', 'SDR', 'PHX', 'ATL', 'MIL', 'POR', 'BUF',
#        'CLE', 'HOU', 'GOS', 'KCK', 'CAP', 'WAS', 'NOJ', 'DEN', 'IND',
#        'SAN', 'NYN', 'NJN', 'SDC', 'UTH', 'DAL', 'LAC', 'SAC', 'CHH',
#        'MIA', 'MIN', 'ORL', 'TOR', 'VAN', 'UTA', 'GSW', 'PHI', 'SAS',
#        'MEM', 'NOH', 'CHA', 'NOK', 'OKC', 'BKN', 'NOP'], dtype=object)

# %%
df['Player'].unique()
# Out:
# array(['Paul Arizin', 'George Mikan', 'Bob Cousy', ..., 'Stanley Umude',
#        'Alondes Williams', 'Michael Foster Jr.'], dtype=object)

# %%
df.isnull().any()
# Out:
# Rank                  False
# Year                  False
# Season Start Year     False
# Season Type           False
# Player ID             False
# Player                False
# Team ID               False
# Team                  False
# Games Played          False
# Minutes Played        False
# FG Made               False
# FG Attempts           False
# FG %                  False
# 3-Pt FG Made           True
# 3-Pt FG Attempts       True
# 3-Pt FG %              True
# FT Made               False
# FT Attempts           False
# FT %                  False
# Offensive Rebounds     True
# Defensive Rebounds     True
# Rebounds              False
# Assists               False
# Steals                 True
# Blocks                 True
# Turnovers              True
# Personal Fouls        False
# Points Scored         False
# Efficency             False
# AST/TOV                True
# STL/TOV                True
# missing_values         True
# Formatted_year        False
# ...

# %%
missing_values = df.isnull().sum() 
missing_values[missing_values > 0]
# Out:
# 3-Pt FG Made           6296
# 3-Pt FG Attempts       6296
# 3-Pt FG %              6296
# Offensive Rebounds     4229
# Defensive Rebounds     4229
# Steals                 4229
# Blocks                 4229
# Turnovers              5566
# AST/TOV                5566
# STL/TOV                5566
# missing_values        33330
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                 Rank     Year  Season Start Year     Season Type  \
# count   33330.000000    33330       33330.000000           33330
# unique           NaN       72                NaN               2
# top              NaN  2021-22                NaN  Regular Season
# freq             NaN      822                NaN           22832
# mean      161.710561      NaN        1995.719742             NaN
# std       126.506757      NaN          18.247299             NaN
# min         1.000000      NaN        1951.000000             NaN
# 25%        59.000000      NaN        1983.000000             NaN
# 50%       130.000000      NaN        1998.000000             NaN
# 75%       240.000000      NaN        2011.000000             NaN
# max       582.000000      NaN        2022.000000             NaN
#
#            Player ID         Player       Team ID   Team  Games Played  \
# count   3.333000e+04          33330  3.333000e+04  33330  33330.000000
# ...

# %%
df.shape
# Out:
# (33330, 32)

# %%
df['Player'].unique
# Out:
# <bound method Series.unique of 0                   Paul Arizin
# 1                  George Mikan
# 2                     Bob Cousy
# 3                   Ed Macauley
# 4                    Bob Davies
#                   ...
# 33325    Thanasis Antetokounmpo
# 33326             Thomas Bryant
# 33327             Udonis Haslem
# 33328             Vlatko Cancar
# 33329         Wendell Moore Jr.
# Name: Player, Length: 33330, dtype: object>

# %%
df['Season Type'].value_counts()
# Out:
# Regular Season    22832
# Playoffs          10498
# Name: Season Type, dtype: int64

# %%
tab = pd.crosstab(df['Player'],df['Season Type'])

# %%
tab
# Out:
# Season Type         Playoffs  Regular Season
# Player
# A.C. Green                13              16
# A.J. Bramlett              0               1
# A.J. English               0               2
# A.J. Guyton                0               3
# A.J. Lawson                0               1
# ...                      ...             ...
# Zion Williamson            0               3
# Zoran Dragic               0               1
# Zoran Planinic             3               3
# Zydrunas Ilgauskas         7              13
# Zylan Cheatham             0               2
#
# [4387 rows x 2 columns]

# %%
df.loc[df['Games Played'].idxmax()]
# Out:
# Rank                              68
# Year                         1999-00
# Season Start Year               1999
# Season Type           Regular Season
# Player ID                        423
# Player                 Chris Gatling
# Team ID                   1610612743
# Team                             DEN
# Games Played                      85
# Minutes Played                  1811
# FG Made                          365
# FG Attempts                      802
# FG %                           0.455
# 3-Pt FG Made                    18.0
# 3-Pt FG Attempts                70.0
# 3-Pt FG %                      0.257
# FT Made                          266
# FT Attempts                      373
# FT %                           0.713
# Offensive Rebounds             154.0
# Defensive Rebounds             348.0
# Rebounds                         502
# Assists                           71
# Steals                          82.0
# Blocks                          23.0
# ...

# %%
df['Games Played'].idxmax()
# Out:
# 17014

# %%
df
# Out:
#        Rank     Year  Season Start Year     Season Type  Player ID  \
# 0         1  1951-52               1951  Regular Season      76056
# 1         2  1951-52               1951  Regular Season     600012
# 2         3  1951-52               1951  Regular Season     600003
# 3         4  1951-52               1951  Regular Season      77429
# 4         5  1951-52               1951  Regular Season      76514
# ...     ...      ...                ...             ...        ...
# 33325   194  2022-23               2022        Playoffs     203648
# 33326   194  2022-23               2022        Playoffs    1628418
# 33327   194  2022-23               2022        Playoffs       2617
# 33328   194  2022-23               2022        Playoffs    1628427
# 33329   194  2022-23               2022        Playoffs    1631111
#
#                        Player     Team ID Team  Games Played  Minutes Played  \
# 0                 Paul Arizin  1610612744  PHW            66            2939
# ...

# %%
df.loc[df['Minutes Played'].idxmax()]
# Out:
# Rank                                 1
# Year                           1961-62
# Season Start Year                 1961
# Season Type             Regular Season
# Player ID                        76375
# Player                Wilt Chamberlain
# Team ID                     1610612744
# Team                               PHW
# Games Played                        80
# Minutes Played                    3882
# FG Made                           1597
# FG Attempts                       3159
# FG %                             0.506
# 3-Pt FG Made                       NaN
# 3-Pt FG Attempts                   NaN
# 3-Pt FG %                          NaN
# FT Made                            835
# FT Attempts                       1363
# FT %                             0.613
# Offensive Rebounds                 NaN
# Defensive Rebounds                 NaN
# Rebounds                          2052
# Assists                            192
# Steals                             NaN
# ...

# %%
df['Year'].str[:-3]
# Out:
# 0        1951
# 1        1951
# 2        1951
# 3        1951
# 4        1951
#          ...
# 33325    2022
# 33326    2022
# 33327    2022
# 33328    2022
# 33329    2022
# Name: Year, Length: 33330, dtype: object

# %%
# #converting year to datetime
# df['Formatted_year'] = pd.to_datetime(df['Year'], format='%Y-%y')
df
# Out:
#        Rank     Year  Season Start Year     Season Type  Player ID  \
# 0         1  1951-52               1951  Regular Season      76056
# 1         2  1951-52               1951  Regular Season     600012
# 2         3  1951-52               1951  Regular Season     600003
# 3         4  1951-52               1951  Regular Season      77429
# 4         5  1951-52               1951  Regular Season      76514
# ...     ...      ...                ...             ...        ...
# 33325   194  2022-23               2022        Playoffs     203648
# 33326   194  2022-23               2022        Playoffs    1628418
# 33327   194  2022-23               2022        Playoffs       2617
# 33328   194  2022-23               2022        Playoffs    1628427
# 33329   194  2022-23               2022        Playoffs    1631111
#
#                        Player     Team ID Team  Games Played  Minutes Played  \
# 0                 Paul Arizin  1610612744  PHW            66            2939
# ...

# %%
# table - year, team - points scored

exp = pd.crosstab(df['Season Start Year'],df['Team'],values = df['Points Scored'], aggfunc = 'sum')

# %%
exp
# Out:
# Team                   ATL     BAL      BKN  BLT      BOS  BUF  CAP     CHA  \
# Season Start Year
# 1951                   NaN  4920.0      NaN  NaN   6316.0  NaN  NaN     NaN
# 1952                   NaN  5256.0      NaN  NaN   6789.0  NaN  NaN     NaN
# 1953                   NaN  5099.0      NaN  NaN   6922.0  NaN  NaN     NaN
# 1954                   NaN     NaN      NaN  NaN   8041.0  NaN  NaN     NaN
# 1955                   NaN     NaN      NaN  NaN   7937.0  NaN  NaN     NaN
# ...                    ...     ...      ...  ...      ...  ...  ...     ...
# 2018                8637.0     NaN   9685.0  NaN  10129.0  NaN  NaN  9502.0
# 2019                7981.0     NaN   8458.0  NaN  10042.0  NaN  NaN  6364.0
# 2020               10503.0     NaN  10154.0  NaN   8839.0  NaN  NaN  8066.0
# 2021                9445.0     NaN   9176.0  NaN  11440.0  NaN  NaN  9971.0
# 2022               11320.0     NaN   9769.0  NaN  12181.0  NaN  NaN  7839.0
#
# ...

# %%
len(df['Team'].unique())
# Out:
# 61

# %%
df[(df['Season Start Year']==1955)&(df['Team']=='ATL')]
# Out:
# Empty DataFrame
# Columns: [Rank, Year, Season Start Year, Season Type, Player ID, Player, Team ID, Team, Games Played, Minutes Played, FG Made, FG Attempts, FG %, 3-Pt FG Made, 3-Pt FG Attempts, 3-Pt FG %, FT Made, FT Attempts, FT %, Offensive Rebounds, Defensive Rebounds, Rebounds, Assists, Steals, Blocks, Turnovers, Personal Fouls, Points Scored, Efficency, AST/TOV, STL/TOV, missing_values, Formatted_year]
# Index: []
#
# [0 rows x 33 columns]

# %%
df[(df['Team']=='CAP')].groupby('Season Start Year')['Points Scored'].sum()
# Out:
# Season Start Year
# 1973    9019
# Name: Points Scored, dtype: int64

# %%
#find out how many years each team has scored points

df1 = df[df['Points Scored'] > 0]

df2 = df1.groupby('Team')['Season Start Year'].value_counts()

df2
# Out:
# Team  Season Start Year
# ATL   2020                 33
#       2021                 33
#       2016                 30
#       2008                 28
#       2012                 28
#                            ..
# WAS   2001                 14
#       2012                 14
#       1989                 13
#       1998                 13
#       1988                 12
# Name: Season Start Year, Length: 1574, dtype: int64

# %%
df_non_zero = df[df['Points Scored'] > 0]

table = pd.pivot_table(df_non_zero, index='team_name', columns='Season Start Year', values = 'Points Scored', aggfunc = 'sum')

table
# Out:
# Season Start Year             1951    1952    1953    1954    1955    1956  \
# team_name
# Atlanta Hawks                  NaN     NaN     NaN     NaN     NaN     NaN
# Baltimore Bullets           4920.0  5256.0  5099.0     NaN     NaN     NaN
# Boston Celtics              6316.0  6789.0  6922.0  8041.0  7937.0  8611.0
# Brooklyn Nets                  NaN     NaN     NaN     NaN     NaN     NaN
# Buffalo Braves                 NaN     NaN     NaN     NaN     NaN     NaN
# Capital/Washington Bullets     NaN     NaN     NaN     NaN     NaN     NaN
# Charlotte Hornets              NaN     NaN     NaN     NaN     NaN     NaN
# Chicago Bulls                  NaN     NaN     NaN     NaN     NaN     NaN
# Chicago Packers/Zephyrs        NaN     NaN     NaN     NaN     NaN     NaN
# Chicago Zephyrs                NaN     NaN     NaN     NaN     NaN     NaN
# Cincinnati Royals              NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
df.groupby('Team')['Points Scored'].sum().sort_values(ascending=False)
# Out:
# Team
# BOS    681956
# LAL    616136
# NYK    612175
# DET    564394
# PHX    502252
#         ...
# INO     10996
# CAP      9019
# CHZ      8809
# CHP      8681
# NYN      6558
# Name: Points Scored, Length: 61, dtype: int64

# %%
df.groupby('team_name')['Points Scored'].sum().sort_values(ascending=False)
# Out:
# team_name
# Boston Celtics                681956
# Los Angeles Lakers            616136
# New York Knicks               612175
# Detroit Pistons               564394
# Philadelphia 76ers            536909
# Phoenix Suns                  502252
# Chicago Bulls                 495080
# Milwaukee Bucks               492406
# Portland Trail Blazers        473654
# Golden State Warriors         472484
# Atlanta Hawks                 472421
# Houston Rockets               468418
# Cleveland Cavaliers           449803
# Denver Nuggets                430155
# San Antonio Spurs             429570
# Indiana Pacers                419537
# Washington Wizards            415070
# Utah Jazz                     388393
# Dallas Mavericks              380299
# Seattle SuperSonics           363697
# Los Angeles Clippers          335723
# Sacramento Kings              323372
# Miami Heat                    309640
# New Jersey Nets               285415
# Orlando Magic                 282853
# ...

# %% [markdown]
# Top 5 Teams with highest scores
#
# BOS    681956
#
# LAL    616136
#
# NYK    612175
#
# DET    564394
#
# PHX    502252

# %%
Top_teams = ['Boston Celtics', 'Los Angeles Lakers', 'New York Knicks ', 'Detroit Pistons', 'Philadelphia 76ers' ]

filter_top_teams = table[table.index.isin(Top_teams)]

filter_top_teams
# Out:
# Season Start Year     1951    1952    1953    1954    1955    1956    1957  \
# team_name
# Boston Celtics      6316.0  6789.0  6922.0  8041.0  7937.0  8611.0  9092.0
# Detroit Pistons        NaN     NaN     NaN     NaN     NaN     NaN  8382.0
# Los Angeles Lakers     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Philadelphia 76ers     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# Season Start Year     1958     1959     1960  ...    2013    2014    2015  \
# team_name                                     ...
# Boston Celtics      9733.0  10808.0  10667.0  ...  7360.0  8476.0  9018.0
# Detroit Pistons     8161.0   8543.0   9926.0  ...  8286.0  7795.0  8645.0
# Los Angeles Lakers     NaN      NaN  10448.0  ...  8331.0  8178.0  7982.0
# Philadelphia 76ers     NaN      NaN      NaN  ...  6333.0  6566.0  7848.0
#
# Season Start Year      2016     2017     2018     2019    2020     2021  \
# team_name
# ...

# %%
for i in range(len(filter_top_teams)-1):
    filter_top_teams.loc[i, "Growth_rate"] = filter_top_teams.iloc[i+1,1] - filter_top_teams.iloc[i, 1]/filter_top_teams.iloc[i, 1] * 100

df_growth_rate = filter_top_teams.groupby('team_name')['Growth_rate'].mean()

df_growth_rate
# Out:
# team_name
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# Boston Celtics       NaN
# Detroit Pistons      NaN
# Los Angeles Lakers   NaN
# Philadelphia 76ers   NaN
# Name: Growth_rate, dtype: float64

# %%
# df['Growth Rate'] = df['Points Scored'].diff(1)/ df['Points Scored'].shift(1) * 100

# df_growth_rate = df.groupby('Team')['Growth Rate'].mean()

# df_growth_rate

# %%
filter_top_teams
# Out:
# Season Start Year     1951    1952    1953    1954    1955    1956    1957  \
# team_name
# Boston Celtics      6316.0  6789.0  6922.0  8041.0  7937.0  8611.0  9092.0
# Detroit Pistons        NaN     NaN     NaN     NaN     NaN     NaN  8382.0
# Los Angeles Lakers     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Philadelphia 76ers     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# Season Start Year     1958     1959     1960  ...    2013    2014    2015  \
# team_name                                     ...
# Boston Celtics      9733.0  10808.0  10667.0  ...  7360.0  8476.0  9018.0
# Detroit Pistons     8161.0   8543.0   9926.0  ...  8286.0  7795.0  8645.0
# Los Angeles Lakers     NaN      NaN  10448.0  ...  8331.0  8178.0  7982.0
# Philadelphia 76ers     NaN      NaN      NaN  ...  6333.0  6566.0  7848.0
#
# Season Start Year      2016     2017     2018     2019    2020     2021  \
# team_name
# ...

# %%
# # Assuming you have a DataFrame called df and the column name is 'Growth_rate'
# filter_top_teams['Growth_rate'] = pd.to_numeric(filter_top_teams['Growth_rate'], errors='coerce')

# filter_top_teams

# %%
# Plotting the pivot table data as a line chart
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
for team in filter_top_teams.index:
    plt.plot(filter_top_teams.columns, filter_top_teams.loc[team],label=team)


plt.xlabel('Years')
plt.ylabel('Points Scored')
plt.title('Points Scored by Teams over the Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
for team in filter_top_teams.index:
    plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
    plt.plot(filter_top_teams.columns, filter_top_teams.loc[team], label=team, c=nba_blue)
    plt.xlabel('Years')
    plt.ylabel('Points Scored')
    plt.title(f'Points Scored by {team} over the Years')
    plt.legend()

    ax = plt.gca()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.show()

# %%
team = 'Los Angeles Lakers'
y = filter_top_teams.columns[filter_top_teams.columns>1996]

plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
plt.plot(y, filter_top_teams.loc[team, filter_top_teams.columns >1996], label=team, c=nba_red)
plt.xlabel('Years')
plt.ylabel('Points Scored')
plt.title(f'Points Scored by {team} over the Years')

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.legend()
# plt.grid(True)
plt.show()

# %%
highest_scores_years = filter_top_teams.idxmax(axis=1).sort_values(ascending=False)

highest_scores_years
# Out:
# team_name
# Boston Celtics        2022
# Los Angeles Lakers    2022
# Detroit Pistons       1987
# Philadelphia 76ers    1966
# dtype: int64

# %%
top_n_years = filter_top_teams.apply(lambda row: row.nlargest(10).index.tolist(), axis=1)

# %%
top_n_years
# Out:
# team_name
# Boston Celtics        [2022, 1986, 1984, 1983, 1967, 2021, 1985, 196...
# Detroit Pistons       [1987, 1986, 1988, 1989, 1984, 1961, 2003, 198...
# Los Angeles Lakers    [2022, 1986, 1984, 1983, 1987, 2007, 1982, 197...
# Philadelphia 76ers    [1966, 2018, 1981, 1967, 1982, 2022, 2017, 197...
# dtype: object

# %% [markdown]
# Brinnging in graphs for games played each season for LAL

# %%
df_non_zero = df[(df['Points Scored'] > 0) & (df['team_name'] == 'Los Angeles Lakers')]

season_table = pd.pivot_table(df_non_zero, index='Season Type', columns='Season Start Year', values = 'Points Scored', aggfunc = 'sum')

season_table
# Out:
# Season Start Year    1960    1961    1962    1963    1964    1965    1966  \
# Season Type
# Playoffs           1411.0  1530.0  1469.0   506.0  1246.0  1629.0   311.0
# Regular Season     9037.0  9505.0  9242.0  8774.0  8880.0  9557.0  9500.0
#
# Season Start Year    1967    1968    1969  ...    2013    2014    2015  \
# Season Type                                ...
# Playoffs           1566.0  1867.0  1869.0  ...     NaN     NaN     NaN
# Regular Season     8959.0  9204.0  8011.0  ...  8331.0  8178.0  7982.0
#
# Season Start Year    2016    2017    2018    2019    2020    2021     2022
# Season Type
# Playoffs              NaN     NaN     NaN  2369.0   585.0     NaN   1797.0
# Regular Season     7717.0  7993.0  9666.0  8394.0  8486.0  9164.0  10492.0
#
# [2 rows x 63 columns]

# %%
x = season_table.columns

team_colors = [nba_red, nba_blue]

# Plotting the pivot table data as a line chart
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
for i, s in enumerate(season_table.index):
    plt.plot(x, season_table.loc[s],label=s, color=team_colors[i % len(team_colors)])

plt.xlabel('Years')
plt.ylabel('Points Scored')
plt.title('Points Scored by Teams over the Years for both the Seasons')
plt.legend()

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# plt.grid(True)
plt.show()

# %% [markdown]
# Plotting pointers made YOY

# %% [markdown]
# Plotting for '3-Pt FG Attempts', '3-Pt FG Made'

# %%
df_non_zero = df[(df['team_name'] == 'Los Angeles Lakers') & (df['Season Type'] == 'Regular Season')]

pointer_table = pd.pivot_table(df_non_zero, index=['Season Start Year'], values=['3-Pt FG Attempts', '3-Pt FG Made'], aggfunc='mean')

pointer_table
# Out:
#                    3-Pt FG Attempts  3-Pt FG Made
# Season Start Year
# 1979                      10.888889      2.222222
# 1980                       6.307692      1.076923
# 1981                       6.714286      0.928571
# 1982                       7.000000      0.866667
# 1983                      16.357143      4.142857
# 1984                      21.071429      6.428571
# 1985                      29.214286      9.857143
# 1986                      37.333333     13.750000
# 1987                      31.866667      9.466667
# 1988                      55.583333     18.916667
# 1989                      60.142857     22.142857
# 1990                      61.916667     18.750000
# 1991                      29.800000      8.000000
# 1992                      45.923077     14.000000
# 1993                      53.533333     16.066667
# 1994                      94.125000     33.000000
# 1995                      97.071429     34.071429
# ...

# %%
top_players['PPG'] = top_players['Points Scored']/top_players['Games Played']
top_players['RPG'] = top_players['Rebounds']/top_players['Games Played']
top_players['APG'] = top_players['Assists']/top_players['Games Played']
top_players['SPG'] = top_players['Steals']/top_players['Games Played']
top_players['BPG'] = top_players['Steals']/top_players['Games Played']
# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(top_players.index, top_players['PPG'], color=nba_blue, label='PPG') # solid nba blue line
plt.plot(top_players.index, top_players['RPG'], color=nba_red, label='RPG') # solid nba red line
plt.plot(top_players.index, top_players['APG'], '--', color=nba_blue, label='APG') # dashed nba blue line
plt.plot(top_players.index, top_players['BPG'], '--', color=nba_red, label='BPG') # dashed nba red line
# Customize the plot
plt.title('Points Scored Per Game')
plt.xlabel('Player')
plt.ylabel('Points Per Game')
plt.xticks(rotation=45, ha='right')
plt.legend()
# Show the plot
plt.tight_layout()
plt.show()

# %%
x = pointer_table.index


plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(pointer_table.index, pointer_table['3-Pt FG Attempts'], label='3-Pt FG Attempts', marker='o',c=nba_blue)
plt.plot(pointer_table.index, pointer_table['3-Pt FG Made'], label='3-Pt FG Made', marker='o',c=nba_red)

# Customize the plot
plt.title('3-Pt FG Attempts and 3-Pt FG Made for Los Angeles Lakers (Regular Season)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend()

# Show the plot
plt.show()

# %%
df_non_zero = df[(df['team_name'] == 'Los Angeles Lakers') & (df['Season Type'] == 'Playoffs')]

pointer_table2 = pd.pivot_table(df_non_zero, index=['Season Start Year'], values=['3-Pt FG Attempts', '3-Pt FG Made'], aggfunc='mean')

# pointer_table


x = pointer_table2.index


plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(pointer_table2.index, pointer_table2['3-Pt FG Attempts'], label='3-Pt FG Attempts', marker='o',c=nba_blue)
plt.plot(pointer_table2.index, pointer_table2['3-Pt FG Made'], label='3-Pt FG Made', marker='o',c=nba_red)

# Customize the plot
plt.title('3-Pt FG Attempts and 3-Pt FG Made for Los Angeles Lakers (Playoffs Season)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend()

# Show the plot
plt.show()

# %%
df_non_zero = df[(df['team_name'] == 'Los Angeles Lakers') & (df['Season Type'] == 'Regular Season')]

pointer_table3 = pd.pivot_table(df_non_zero, index=['Season Start Year'], values=['FT Attempts', 'FT Made'], aggfunc='mean')

# pointer_table


x = pointer_table3.index


plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(pointer_table3.index, pointer_table3['FT Attempts'], label='FT Attempts',marker='o',c=nba_blue)
plt.plot(pointer_table3.index, pointer_table3['FT Made'], label='FT Made',marker='o',c=nba_red)

# Customize the plot
plt.title('FT Attempts, FT Made for Los Angeles Lakers (Regular Season)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend()

# Show the plot
plt.show()

# %%
df_non_zero = df[(df['team_name'] == 'Los Angeles Lakers') & (df['Season Type'] == 'Playoffs')]

pointer_table3 = pd.pivot_table(df_non_zero, index=['Season Start Year'], values=['FT Attempts', 'FT Made'], aggfunc='mean')

# pointer_table


x = pointer_table3.index


plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(pointer_table3.index, pointer_table3['FT Attempts'], label='FT Attempts',marker='o',c=nba_blue)
plt.plot(pointer_table3.index, pointer_table3['FT Made'], label='FT Made',marker='o',c=nba_red)

# Customize the plot
plt.title('FT Attempts, FT Made for Los Angeles Lakers (Playoff Season)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend()

# Show the plot
plt.show()

# %%
df_non_zero = df[(df['team_name'] == 'Los Angeles Lakers') & (df['Season Type'] == 'Regular Season')]

pointer_table4 = pd.pivot_table(df_non_zero, index=['Season Start Year'], values=['FG Attempts', 'FG Made'], aggfunc='mean')

# pointer_table


x = pointer_table4.index


plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(pointer_table4.index, pointer_table4['FG Attempts'], label='FG Attempts',marker='o',c=nba_blue)
plt.plot(pointer_table4.index, pointer_table4['FG Made'], label='FG Made',marker='o',c=nba_red)

# Customize the plot
plt.title('FG Attempts, FG Made for Los Angeles Lakers (Regular Season)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend()

# Show the plot
plt.show()

# %%
df_non_zero = df[(df['team_name'] == 'Los Angeles Lakers') & (df['Season Type'] == 'Playoffs')]

pointer_table4 = pd.pivot_table(df_non_zero, index=['Season Start Year'], values=['FG Attempts', 'FG Made'], aggfunc='mean')

# pointer_table


x = pointer_table4.index


plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(pointer_table4.index, pointer_table4['FG Attempts'], label='FG Attempts',marker='o',c=nba_blue)
plt.plot(pointer_table4.index, pointer_table4['FG Made'], label='FG Made',marker='o',c=nba_red)

# Customize the plot
plt.title('FG Attempts, FG Made for Los Angeles Lakers (Playoff Season)')
plt.xlabel('Year')
plt.ylabel('Values')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Now analyzing top players who are contributing

# %%
# Create a list of team names you want to analyze
teams_to_analyze = ['Los Angeles Lakers']

top_5_players = points_by_player.nlargest(6)

# Step 1: Create a DataFrame to store the aggregate statistics for key players
key_players_stats = pd.DataFrame(columns=['Player','Games Played', 'Minutes Played', 'Team', 'Season Start Year', 'Points Scored', 'Rebounds', 'Assists', 'Steals', 'Blocks', 'Turnovers', 'Efficency', 'AST/TOV', 'STL/TOV','FG Made',
    'FG Attempts',
    'FG %',
    '3-Pt FG Made',
    '3-Pt FG Attempts',
    '3-Pt FG %',
    'FT Made',
    'FT Attempts',
    'FT %',
    'Season Type'])


    
# Step 4: Filter data for the specific team and their top years
filtered_data = df[(df['team_name'] == team_name) ]

# Step 5: Append the filtered data to the key players DataFrame
key_players_stats = key_players_stats.append(filtered_data, ignore_index=True)

# Step 6: Group the key players DataFrame by 'Player' to get player-wise statistics
grouped_by_player = key_players_stats.groupby('Player')

# Step 7: Calculate aggregate statistics for each player during the top years
aggregate_stats = grouped_by_player.agg({
    'Points Scored': 'sum',
    'Games Played':'sum',
    'Minutes Played':'sum',
    'Rebounds': 'sum',
    'Assists': 'sum',
    'Steals': 'sum',
    'Blocks': 'sum',
    'Turnovers': 'sum',
    'Efficency': 'mean',
    'AST/TOV': 'mean',
    'STL/TOV': 'mean',
    'FG Made':'sum',
    'FG Attempts':'sum',
    'FG %':'mean',
    '3-Pt FG Made':'sum',
    '3-Pt FG Attempts':'sum',
    '3-Pt FG %':'mean',
    'FT Made':'sum',
    'FT Attempts':'sum',
    'FT %':'mean',
    'Season Start Year': 'first',
    'Season Type':'first'

})

# Step 8: Sort and identify key players based on aggregate statistics
top_players = aggregate_stats.sort_values(by='Efficency', ascending=False).groupby('Season Type').head(10)

top_players

# Display the top players for the selected teams
# Out:
# /var/folders/vt/wdrhl4rs5597cswnpqzm0r340000gn/T/ipykernel_3334/2960333212.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   key_players_stats = key_players_stats.append(filtered_data, ignore_index=True)
#                     Points Scored Games Played Minutes Played Rebounds  \
# Player
# Russell Westbrook            1441           78           2678      580
# Wilt Chamberlain             7250          419          18556     8307
# Kareem Abdul-Jabbar         28246         1273          43787    11804
# Magic Johnson               21408         1096          40783     8024
# LeBron James                 8726          321          11400     2679
# Elmore Smith                 1915          160           5434     1769
# Caron Butler                 1195           77           2747      450
# Shaquille O'Neal            17278          636          24322     7720
# ...

# %%
top_players['PPG'] = top_players['Points Scored']/top_players['Games Played']


# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(top_players.index, top_players['Efficency'], color=nba_blue)


# Customize the plot
plt.title('Points Scored Per Game')
plt.xlabel('Player')
plt.ylabel('Points Per Game')
plt.xticks(rotation=45, ha='right')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
top_players['PPG'] = top_players['Points Scored']/top_players['Games Played']
top_players['RPG'] = top_players['Rebounds']/top_players['Games Played']
top_players['APG'] = top_players['Assists']/top_players['Games Played']
top_players['SPG'] = top_players['Steals']/top_players['Games Played']
top_players['BPG'] = top_players['Steals']/top_players['Games Played']

# %% [markdown]
# Below Data Analysis is for Los Angeles Lakers!!

# %%
categories = ['PPG', 'RPG', 'APG', 'SPG', 'BPG']


top_players['PPG'] = pd.to_numeric(top_players['PPG'], errors='coerce')

# Select the top 5 players based on a criterion (e.g., highest PPG)
top_5_players = top_players.nlargest(5, 'PPG')


abbreviations = {'PPG': 'Points Per Game', 'RPG': 'Rebounds Per Game', 'APG': 'Assists Per Game', 'SPG': 'Steals Per Game', 'BPG': 'Blocks Per Game'}


# Create a single radar chart with subplots
num_players = len(top_5_players)
num_categories = len(categories)
fig, axes = plt.subplots(1, num_players, figsize=(4 * num_players, 6), subplot_kw={'polar': True})
fig.subplots_adjust(wspace=0.4)

# Generate radar chart for each player's efficiency across categories
for i, (player_name, player_row) in enumerate(top_5_players.iterrows()):
    player_stats = player_row[categories]

    ax = axes[i]

    # Calculate angles for categories
    angles = np.linspace(0, 2 * np.pi, num_categories, endpoint=False)

    # Plot data and fill area
    ax.plot(angles, player_stats, color=nba_blue, linewidth=2, marker='o', markersize=6)
    ax.fill(angles, player_stats, color=nba_red, alpha=0.3)

    # Set labels and title
    ax.set_xticks(angles)
    ax.set_xticklabels(categories, fontsize=10)
    ax.set_yticklabels([])

    ax.set_title(f'{player_name}', fontsize=12, pad=10)

    # Set the radial axis to start from the top
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)

    # Adding a grid
    ax.grid(True, linestyle='--', alpha=0.5)

abbreviations_text = "\n".join([f"{abbrev}: {full}" for abbrev, full in abbreviations.items()])
fig.text(0.02, 0.02, abbreviations_text, fontsize=10, verticalalignment='bottom')

# Adjust layout
plt.tight_layout()
plt.show()
